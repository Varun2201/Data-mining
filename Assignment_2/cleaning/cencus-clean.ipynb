# %%
import pandas as pd 
data = pd.read_csv('C-18.csv')

# %%
data_frame = pd.read_excel('census.xlsx')

# %%
data_frame.drop(data_frame[data_frame['Level']=='DISTRICT'].index,inplace=True)

# %%
data_ref = data_frame[['Level','Name', 'TRU', 'No_HH', 'TOT_P', 'TOT_M', 'TOT_F']]

# %%
data_ref.to_csv('Census_clean.csv')
# Out:
#       Level                       Name    TRU      No_HH       TOT_P  \
# 0     India                      India  Total  249501663  1210854977
# 1     India                      India  Rural  168612897   833748852
# 2     India                      India  Urban   80888766   377106125
# 3     STATE            JAMMU & KASHMIR  Total    2119718    12541302
# 4     STATE            JAMMU & KASHMIR  Rural    1553433     9108060
# ...     ...                        ...    ...        ...         ...
# 2002  STATE                 PUDUCHERRY  Rural      95018      395200
# 2003  STATE                 PUDUCHERRY  Urban     207432      852753
# 2016  STATE  ANDAMAN & NICOBAR ISLANDS  Total      94551      380581
# 2017  STATE  ANDAMAN & NICOBAR ISLANDS  Rural      58530      237093
# 2018  STATE  ANDAMAN & NICOBAR ISLANDS  Urban      36021      143488
#
#           TOT_M      TOT_F
# 0     623270258  587584719
# 1     427781058  405967794
# 2     195489200  181616925
# ...
