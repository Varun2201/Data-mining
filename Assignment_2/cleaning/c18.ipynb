# %%
import pandas as pd 
import numpy as numpy

# %%
data_frame = pd.read_excel('DDW-C18-0000.xlsx')

# %%
data_frame.columns=['State_code','D_id','Area_name','Type','Age_grp','Person-second','Male-second','female-second','Person-third','Male-third','female-third']

# %%
data_frame.drop([0,1,2,3,4],inplace=True)

# %%
data_frame.to_csv('C-18.csv')

# %%
data_frame[0:10]
# Out:
#    State_code D_id Area_name   Type         Age_grp Person-second Male-second  \
# 5          00   00     INDIA  Total           Total     314988770   176696383
# 6          00   00     INDIA  Total             5-9      15649192     8166843
# 7          00   00     INDIA  Total           10-14      34488492    18133423
# 8          00   00     INDIA  Total           15-19      42424599    22750908
# 9          00   00     INDIA  Total           20-24      41344406    22386694
# 10         00   00     INDIA  Total           25-29      35924045    19695033
# 11         00   00     INDIA  Total           30-49      96443870    55866320
# 12         00   00     INDIA  Total           50-69      39729782    24306735
# 13         00   00     INDIA  Total             70+       7962347     4813671
# 14         00   00     INDIA  Total  Age not stated       1022037      576756
#
#    female-second Person-third Male-third female-third
# 5      138292387     86009580   50536832     35472748
# ...
